# %%
pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      ------------------------ -------------- 30.7/48.7 kB 72.9 kB/s eta 0:00:01
# ...
