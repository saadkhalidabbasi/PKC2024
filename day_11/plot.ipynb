# %% [markdown]
# ## Plotting In Python
#
# by Saad Khalid Abbasi

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# importing data set 

kashti=sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Checking Nul values 
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ##  Bar Plot

# %%
kashti.survived.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot(x='survived',hue='who', data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='survived',hue='sex',data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# ### Scattter Plot

# %%
# Scatter Plot 

plt.scatter(data=kashti,x='age', y='fare')

# %%
# For Making the scatter plot , both the axis values should be numeric 

sns.scatterplot(data=kashti,x='age',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(data=kashti,x='sex',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# For A bigger version of Graph, We Make A pair Graph 

sns.pairplot(kashti)

# %% [markdown]
# ## Hist Plot

# %%
kashti.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.hist(bins=10,figsize=(9,7),grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(data=kashti,x='sex',y='fare',hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(data=kashti,x='sex',y='fare',hue='embark_town')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# Changing the titles of X and Y axis .

sns.scatterplot(data=kashti, x='fare',y='age',hue='sex')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
# Making A Grid Plot 
g=sns.FacetGrid(kashti,hue='survived',col='pclass',margin_titles=True,palette={1:'seagreen',0:'black'})

g=g.map(plt.scatter,"age","fare",edgecolor='w').add_legend()

# %%
g=sns.FacetGrid(kashti,hue='survived',col='sex',margin_titles=True,palette={1:'seagreen',0:'black'})

g=g.map(plt.scatter,"age","fare",edgecolor='w').add_legend()

# %%
sns.stripplot(data=kashti,x='sex',y='fare',hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %% [markdown]
# ### Heat Map

# %%
corr=kashti.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 corr=kashti.corr()
#
# File c:\Users\FATTANI COMPUTERS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\FATTANI COMPUTERS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
# ...

# %%
sns.violinplot(data=kashti,x='sex',y='fare',hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>
