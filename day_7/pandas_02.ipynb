# %% [markdown]
#  ### How to Import DataSet in python using Pandas Library
#
# Created by Saad Khalid Abbasi
#
# Date:04/01/2024

# %%
import pandas as pd

# %%
# pd.read_excel("pandas_01_day6.xlsx")
# Assign it in a Variable named df 

df =pd.read_excel("pandas_01_day6.xlsx")

# %%
# For Print we will simply write variable name like df 
df
# Out:
#     Height  Weight Favourite Dish
# 0      5.8     101  Chicken Pulao
# 1      6.2      92        Biryani
# 2      5.9      62  Karahi Ghosht
# 3      5.9      95  Chicken Pulao
# 4      5.9      55  Chicken Pulao
# ..     ...     ...            ...
# 82     5.4      55          Pasta
# 83     5.9      72  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani
#
# [87 rows x 3 columns]

# %% [markdown]
# View DataFrames in Pandas

# %%
df.head()
# Out:
#    Height  Weight Favourite Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao

# %%
df.tail()
# Out:
#     Height  Weight Favourite Dish
# 82     5.4      55          Pasta
# 83     5.9      72  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani

# %% [markdown]
# If we want to customize no of entries in head or tail , we will simply add the number in the argument section or in the paranthesis

# %%
df.head(10)
# Out:
#    Height  Weight Favourite Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# 5     5.3      59        Biryani
# 6     5.6      50          Pasta
# 7     5.9      76        Biryani
# 8     5.1      78        Biryani
# 9     5.4      68        Biryani

# %%
df.tail(3)
# Out:
#     Height  Weight Favourite Dish
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Height          87 non-null     float64
#  1   Weight          87 non-null     int64
#  2   Favourite Dish  87 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df.shape
# Out:
# (87, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=87, step=1)

# %%
df.columns
# Out:
# Index(['Height', 'Weight', 'Favourite Dish'], dtype='object')

# %%
df.describe()
# Out:
#           Height      Weight
# count  87.000000   87.000000
# mean    5.545517   70.390805
# std     0.327115   16.741090
# min     5.000000   25.000000
# 25%     5.300000   60.000000
# 50%     5.600000   70.000000
# 75%     5.800000   80.000000
# max     6.200000  125.000000

# %% [markdown]
# For Transpose of the Data , we will use following method

# %%
df.T
# Out:
#                            0        1              2              3   \
# Height                    5.8      6.2            5.9            5.9
# Weight                    101       92             62             95
# Favourite Dish  Chicken Pulao  Biryani  Karahi Ghosht  Chicken Pulao
#
#                            4        5      6        7        8        9   ...  \
# Height                    5.9      5.3    5.6      5.9      5.1      5.4  ...
# Weight                     55       59     50       76       78       68  ...
# Favourite Dish  Chicken Pulao  Biryani  Pasta  Biryani  Biryani  Biryani  ...
#
#                      77             78       79     80             81     82  \
# Height              5.5           5.11      5.3    5.4            5.5    5.4
# Weight               85             72       62     55             52     55
# Favourite Dish  Biryani  Karahi Ghosht  Biryani  Pasta  Karahi Ghosht  Pasta
#
#                            83       84             85       86
# ...

# %%
df.sort_index()
# Out:
#     Height  Weight Favourite Dish
# 0      5.8     101  Chicken Pulao
# 1      6.2      92        Biryani
# 2      5.9      62  Karahi Ghosht
# 3      5.9      95  Chicken Pulao
# 4      5.9      55  Chicken Pulao
# ..     ...     ...            ...
# 82     5.4      55          Pasta
# 83     5.9      72  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani
#
# [87 rows x 3 columns]

# %%
df.sort_index(ascending=False)
# Out:
#     Height  Weight Favourite Dish
# 86     5.1      96        Biryani
# 85     6.2      68  Chicken Pulao
# 84     5.4      61        Biryani
# 83     5.9      72  Karahi Ghosht
# 82     5.4      55          Pasta
# ..     ...     ...            ...
# 4      5.9      55  Chicken Pulao
# 3      5.9      95  Chicken Pulao
# 2      5.9      62  Karahi Ghosht
# 1      6.2      92        Biryani
# 0      5.8     101  Chicken Pulao
#
# [87 rows x 3 columns]

# %% [markdown]
# If we want to sort by a specific coloumns or special variable like height, weight or favourite dish

# %%
df.sort_values(by='Weight')
# Out:
#     Height  Weight Favourite Dish
# 26     5.0      25        Biryani
# 35     5.0      31        Biryani
# 44     5.2      48        Biryani
# 42     5.6      49  Chicken Pulao
# 40     5.0      50  Chicken Pulao
# ..     ...     ...            ...
# 86     5.1      96        Biryani
# 0      5.8     101  Chicken Pulao
# 33     5.1     103    Chapel Kaba
# 34     6.0     110    Chapel Kaba
# 75     6.0     125    Chapel Kaba
#
# [87 rows x 3 columns]

# %%
df.sort_values('Height')
# Out:
#     Height  Weight Favourite Dish
# 40     5.0      50  Chicken Pulao
# 26     5.0      25        Biryani
# 15     5.0      57        Biryani
# 35     5.0      31        Biryani
# 86     5.1      96        Biryani
# ..     ...     ...            ...
# 20     6.0      85        Biryani
# 25     6.0      50        Biryani
# 12     6.1      78        Biryani
# 1      6.2      92        Biryani
# 85     6.2      68  Chicken Pulao
#
# [87 rows x 3 columns]
